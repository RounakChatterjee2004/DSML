# %%
import pandas as pd

# %%
data=pd.read_csv("dataset/Telecom Churn.csv")

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# #1.Minimum Values

# %%
print(data.min())
# Out:
# state                           AK
# account length                   1
# area code                      408
# phone number              327-1058
# international plan              no
# voice mail plan                 no
# number vmail messages            0
# total day minutes              0.0
# total day calls                  0
# total day charge               0.0
# total eve minutes              0.0
# total eve calls                  0
# total eve charge               0.0
# total night minutes           23.2
# total night calls               33
# total night charge            1.04
# total intl minutes             0.0
# total intl calls                 0
# total intl charge              0.0
# customer service calls           0
# churn                        False
# dtype: object

# %% [markdown]
# #2.Maximum Values

# %%
print(data.max())
# Out:
# state                           WY
# account length                 243
# area code                      510
# phone number              422-9964
# international plan             yes
# voice mail plan                yes
# number vmail messages           51
# total day minutes            350.8
# total day calls                165
# total day charge             59.64
# total eve minutes            363.7
# total eve calls                170
# total eve charge             30.91
# total night minutes          395.0
# total night calls              175
# total night charge           17.77
# total intl minutes            20.0
# total intl calls                20
# total intl charge              5.4
# customer service calls           9
# churn                         True
# dtype: object

# %% [markdown]
# #3.Mean Values

# %%
print(data['total day calls'].mean())
print(data['total day minutes'].mean())
print(data['total day charge'].mean())

# print(data.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 # print(data['total day calls'].mean())
#       2 # print(data['total day minutes'].mean())
#       3 # print(data['total day charge'].mean())
# ----> 5 print(data.mean())
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
# ...

# %% [markdown]
# #4 Range Values

# %%
#(Range represents the diference between highest values and lowest values)
#1 Range of total day mintues
print(data['total day minutes'].max()-data['total day minutes'].min())
print(data['total day charge'].max()-data['total day charge'].min())
# Out:
# 350.8
# 59.64

# %% [markdown]
# #5.Standard Deviation

# %%
print(data['total day minutes'].std())
print(data['total day charge'].std())
# Out:
# 54.46738920237137
# 9.2594345539305

# %% [markdown]
# #6.Variance

# %%
print(data['total day minutes'].var())
print(data['total day charge'].var())
# Out:
# 2966.696486522602
# 85.73712825852212

# %% [markdown]
# #7.Percentiles (25th, 50th, 75th)
# #The code percentiles_values = data['total day calls'].quantile([0.25, 0.50, 0.75]) is calculating the percentiles of the 'total day calls' column in the data DataFrame. The quantile function returns values at specific percentiles for the data, in this case, the 25th, 50th, and 75th percentiles.
#
# #0.25 (25th percentile): This represents the value below which 25% of the data points fall. In your case, 87 means that 25% of the entries in 'total day calls' are less than or equal to 87.
# #0.50 (50th percentile or median): This represents the middle value of the data. 101 means that half of the data points are less than or equal to 101.
# #0.75 (75th percentile): This represents the value below which 75% of the data points fall. 114 means that 75% of the entries in 'total day calls' are less than or equal to 114.

# %%
percentiles_values = data['total day calls'].quantile([0.25, 0.50, 0.75])
print(percentiles_values)
# Out:
# 0.25     87.0
# 0.50    101.0
# 0.75    114.0
# Name: total day calls, dtype: float64
