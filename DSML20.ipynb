# %%
import pandas as pd
df=pd.read_csv("/content/IRIS.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
import numpy as np
# Load Iris dataset
df = pd.DataFrame(df)
# Features (exclude species column)
X = df.drop("species", axis=1).values  # Only the numerical columns are used for clustering

# Initial centroids (randomly picking from dataset)
m1 = X[0]  # First data point as the initial centroid
m2 = X[50]  # 51st data point as another centroid
m3 = X[100]  # 101st data point as the third centroid

# Function to calculate Euclidean distance
def euclidean_distance(point, centroid):
    return np.sqrt(np.sum((point - centroid) ** 2))

# Perform one iteration of K-means
def k_means_iteration(X, m1, m2, m3):
    cluster1, cluster2, cluster3 = [], [], []
    for point in X:
        # Calculate distances to centroids
        dist_to_m1 = euclidean_distance(point, m1)
        dist_to_m2 = euclidean_distance(point, m2)
        dist_to_m3 = euclidean_distance(point, m3)

        # Assign point to the nearest centroid
        if dist_to_m1 < dist_to_m2 and dist_to_m1 < dist_to_m3:
            cluster1.append(point)
        elif dist_to_m2 < dist_to_m1 and dist_to_m2 < dist_to_m3:
            cluster2.append(point)
        else:
            cluster3.append(point)

    # Update centroids
    new_m1 = np.mean(cluster1, axis=0) if cluster1 else m1
    new_m2 = np.mean(cluster2, axis=0) if cluster2 else m2
    new_m3 = np.mean(cluster3, axis=0) if cluster3 else m3
    return np.array(cluster1), np.array(cluster2), np.array(cluster3), new_m1, new_m2, new_m3

# Run 10 iterations
for i in range(10):
    print(f"Iteration {i+1}")

    cluster1, cluster2, cluster3, m1, m2, m3 = k_means_iteration(X, m1, m2, m3)

    # Results after each iteration
    print("Cluster 1 (around m1):", cluster1.shape[0], "points")
    print("Cluster 2 (around m2):", cluster2.shape[0], "points")
    print("Cluster 3 (around m3):", cluster3.shape[0], "points")
    print("Updated centroid m1:", m1)
    print("Updated centroid m2:", m2)
    print("Updated centroid m3:", m3)
    print("\n")
# Out:
# Iteration 1
# Cluster 1 (around m1): 37 points
# Cluster 2 (around m2): 104 points
# Cluster 3 (around m3): 9 points
# Updated centroid m1: [4.84864865 3.22432432 1.4972973  0.25405405]
# Updated centroid m2: [6.23653846 2.93557692 4.7625     1.61826923]
# Updated centroid m3: [5.38888889 3.72222222 1.45555556 0.23333333]
#
#
# Iteration 2
# Cluster 1 (around m1): 31 points
# Cluster 2 (around m2): 98 points
# Cluster 3 (around m3): 21 points
# Updated centroid m1: [4.79354839 3.13548387 1.5516129  0.28064516]
# Updated centroid m2: [6.2877551  2.88061224 4.94183673 1.68877551]
# Updated centroid m3: [5.31904762 3.74285714 1.4952381  0.26666667]
#
#
# Iteration 3
# Cluster 1 (around m1): 30 points
# Cluster 2 (around m2): 97 points
# Cluster 3 (around m3): 23 points
# Updated centroid m1: [4.78333333 3.08666667 1.62       0.30666667]
# Updated centroid m2: [6.30103093 2.88659794 4.95876289 1.69587629]
# Updated centroid m3: [5.29565217 3.7173913  1.48695652 0.26521739]
#
#
# ...
